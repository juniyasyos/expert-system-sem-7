# %% [markdown]
# # 🌟 Fuzzy Logic Basics - Dasar-Dasar Logika Fuzzy
#
# ## Tujuan Pembelajaran
# Dalam notebook ini, Anda akan mempelajari:
# 1. **Perbedaan Crisp vs Fuzzy** - Memahami mengapa fuzzy logic diperlukan
# 2. **Fuzzy Sets** - Himpunan fuzzy dan derajat keanggotaan
# 3. **Membership Functions** - Fungsi keanggotaan (Triangular, Trapezoidal, Gaussian)
# 4. **Fuzzifikasi** - Mengubah nilai crisp menjadi fuzzy
# 5. **Fuzzy Operations** - Operasi AND, OR, NOT pada fuzzy sets
#
# ## Apa itu Fuzzy Logic?
#
# **Fuzzy Logic** adalah pendekatan untuk menangani ketidakpastian dan nilai yang tidak tegas (fuzzy).
#
# ### Contoh Sederhana:
# - **Crisp Logic**: "Suhu 25°C = TIDAK PANAS (0) atau PANAS (1)"
# - **Fuzzy Logic**: "Suhu 25°C = 30% DINGIN, 60% HANGAT, 10% PANAS"
#
# Fuzzy logic lebih natural untuk menggambarkan dunia nyata!
